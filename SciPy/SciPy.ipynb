# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

from scipy import optimize     
from scipy import integrate    
from scipy import stats

# %%
# 选中单元格后 按esc+m 可以将此单元格切换为.md格式 用.md语法写完编译就会生成.md格式的笔记 公式通过$...$插入

# %% [markdown]
# # 选中单元格后 按esc+m 可以将此单元格切换为.md格式 用.md语法写完编译就会生成.md格式的笔记 公式通过美元符号插入
