# %%
# --- Cell 1: Imports ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 设置显示选项，避免 DataFrame 显示不全
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)
np.set_printoptions(precision=4, suppress=True) # 保持输出整洁，不显示科学计数法

print("✅ 环境加载完毕，随时可以开始计算！")
# Out:
# ✅ 环境加载完毕，随时可以开始计算！
